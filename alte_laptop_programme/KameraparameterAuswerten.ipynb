# %%
import numpy as np

data = np.load(r"G:\Meine Ablage\Studium\Master\3. Semester\Masterprojekt\Bilder\calibration_data_01.npz")

mtx = data["mtx"]
dist = data["dist"]

# %%
print(mtx)
print(dist)
# Out:
# [[999.38669285   0.         368.193586  ]
#  [  0.         993.44502698 237.5743247 ]
#  [  0.           0.           1.        ]]
# [[-3.96441708e-01  3.18458851e-01 -4.31852792e-03 -2.30932876e-03
#   -2.80693126e+00]]
